# %%
import pandas as pd

# %%
results = pd.read_csv('../Cleaned Data/Daily Game Result.csv')
results.head()
# Out:
#        Date       HomeTeam     AwayTeam  Type  Final_Score_A  Final_Score_B  \
# 0  1/1/2002       Charlton      Ipswich  Home              3              2
# 1  1/1/2002        Chelsea  Southampton  Home              2              4
# 2  1/1/2002          Leeds     West Ham  Home              3              0
# 3  1/1/2002      Liverpool       Bolton  Home              1              1
# 4  1/1/2002  Middlesbrough      Everton  Home              1              0
#
#    Final_Points  Win_Count  Draw_Count  Loss_Count  Half_Score_A  \
# 0             3          1           0           0             2
# 1             0          0           0           1             2
# 2             3          1           0           0             2
# 3             1          0           1           0             0
# 4             3          1           0           0             0
#
#    Half_Score_B  Half_Points
# 0             2            1
# 1             1            3
# ...

# %%
results
# Out:
#            Date       HomeTeam       AwayTeam  Type Final_Score_A  \
# 0      13/08/11      Blackburn         Wolves  Home             1
# 1      13/08/11         Fulham    Aston Villa  Home             0
# 2      13/08/11      Liverpool     Sunderland  Home             1
# 3      13/08/11      Newcastle        Arsenal  Home             0
# 4      13/08/11            QPR         Bolton  Home             0
# 5      13/08/11          Wigan        Norwich  Home             1
# 6      14/08/11          Stoke        Chelsea  Home             0
# 7      14/08/11      West Brom     Man United  Home             1
# 8      15/08/11       Man City        Swansea  Home             4
# 9      20/08/11        Arsenal      Liverpool  Home             0
# 10     20/08/11    Aston Villa      Blackburn  Home             3
# 11     20/08/11        Chelsea      West Brom  Home             2
# 12     20/08/11        Everton            QPR  Home             0
# ...

# %%
tmp = results['Date'].str.split("/")[:][2]
tmp
# Out:
# ['13', '08', '11']

# %%
results.to_csv('../Cleaned Data/Daily Game Result.csv')
